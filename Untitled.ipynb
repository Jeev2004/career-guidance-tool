# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\MOHANKUMAR\Downloads\ELECTRONICS - Sheet1 (1).csv")

# %%
data['CONTROL SYSTEMS'] = data['CONTROL SYSTEMS'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['CIRCUIT DESIGN'] = data['CIRCUIT DESIGN'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['POWER ELECTRONICS'] = data['POWER ELECTRONICS'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['RF'] = data['RF'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['C++'] = data['C++'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['ELECTRICAL SYSTEM'] = data['ELECTRICAL SYSTEM'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['CAD'] = data['CAD'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['PCB'] = data['PCB'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['LABVIEW'] = data['LABVIEW'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')
data['ANALOG COMMUNICATION'] = data['ANALOG COMMUNICATION'].map({'POOR':0,'BEGINNER':1,'AVERAGE':2,'INTERMEDIATE':3,'EXCELLENT':4,'PROFESSIONAL':5}).astype('int')

# %%
data['ROLE'].fillna(1,inplace=True)
del data['ROLES']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ROLES'
#
# ...

# %%
data
data.drop(['ROLES'],axis=1)
# Out:
#     CIRCUIT DESIGN  CONTROL SYSTEMS  POWER ELECTRONICS  ANALOG COMMUNICATION  \
# 0                0                1                  1                     5
# 1                1                1                  4                     5
# 2                2                2                  2                     2
# 3                3                2                  3                     2
# 4                3                0                  3                     2
# 5                5                4                  4                     5
# 6                1                0                  1                     3
# 7                2                2                  3                     3
# 8                2                1                  1                     2
# 9                3                2                  3                     2
# 10               2                3                  2                     3
# ...

# %%
X = data.drop('ROLE',axis=1)
X
# Out:
#     CIRCUIT DESIGN  CONTROL SYSTEMS  POWER ELECTRONICS  ANALOG COMMUNICATION  \
# 0                0                1                  1                     5
# 1                1                1                  4                     5
# 2                2                2                  2                     2
# 3                3                2                  3                     2
# 4                3                0                  3                     2
# 5                5                4                  4                     5
# 6                1                0                  1                     3
# 7                2                2                  3                     3
# 8                2                1                  1                     2
# 9                3                2                  3                     2
# 10               2                3                  2                     3
# ...

# %%
y= data['ROLE'].astype('int')
y
# Out:
# 0     1
# 1     1
# 2     4
# 3     0
# 4     0
# 5     0
# 6     1
# 7     3
# 8     2
# 9     0
# 10    6
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 17    1
# 18    5
# 19    0
# 20    0
# 21    0
# 22    2
# 23    1
# 24    5
# 25    0
# 26    0
# 27    0
# 28    7
# 29    0
# 30    6
# 31    0
# 32    3
# 33    6
# 34    6
# 35    0
# 36    0
# 37    1
# 38    0
# 39    1
# Name: ROLE, dtype: int32

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.25

# %%
import numpy as np
rf_grid={'n_estimators':np.arange(10,1000,10),'max_features':['auto','sqrt'],'max_depth':[None,3,5,10,20,30],'min_samples_split':[2,5,20,50,100],'min_samples_leaf':[1,2,5,10]}

# %%
rs_rf=RandomizedSearchCV(RandomForestClassifier(),param_distributions=rf_grid,cv=5,n_iter=20,verbose=True)

# %%
rs_rf.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\MOHANKUMAR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\MOHANKUMAR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
rs_rf.best_score_
# Out:
# 0.55

# %%
rs_rf.best_params_
# Out:
# {'n_estimators': 900,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 30}

# %%
rf = RandomForestClassifier(n_estimators= 900,
 min_samples_split = 2,
 min_samples_leaf = 2,
 max_features = 'auto',
 max_depth = 30)

# %%
x = data.drop('ROLE',axis=1)
y=data['ROLE']
rf.fit(X,y)
# Out:
# C:\Users\MOHANKUMAR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=30, max_features='auto', min_samples_leaf=2,
#                        n_estimators=900)

# %%
import joblib
joblib.dump(rf,'career_guidance_predict')
model = joblib.load('career_guidance_predict')
data
# Out:
#     CIRCUIT DESIGN  CONTROL SYSTEMS  POWER ELECTRONICS  ANALOG COMMUNICATION  \
# 0                0                1                  1                     5
# 1                1                1                  4                     5
# 2                2                2                  2                     2
# 3                3                2                  3                     2
# 4                3                0                  3                     2
# 5                5                4                  4                     5
# 6                1                0                  1                     3
# 7                2                2                  3                     3
# 8                2                1                  1                     2
# 9                3                2                  3                     2
# 10               2                3                  2                     3
# ...

# %%
a = pd.DataFrame({
'CIRCUIT DESIGN': 2,
'CONTROL SYSTEMS':1,
'POWER ELECTRONICS':4,    
'ANALOG COMMUNICATION':2,
'RF':3,
'C++':2,
'ELECTRICAL SYSTEM':1,
'CAD':2,
'PCB':2,
'LABVIEW':4},index=[0])
predict1 = model.predict(a)

# %%
print(predict1)
# Out:
# [1.]
